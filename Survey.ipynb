# %%
from PIL import Image
import requests
from io import BytesIO
import matplotlib.pyplot as plt

questions = [['Какой твой любимый цвет?',
              'Чем бы ты предпочла заниматься в свободное время?',
              'Какой предмет вызывает у тебя наибольший интерес?',
              'Что из предложенных вариантов ты бы предпочла надеть?',
              'Какое место из представленных фотографий ты бы предпочел посетить?'],
             ['Какой твой любимый цвет?',
              'Чем бы ты предпочел заниматься в свободное время?',
              'Какой предмет вызывает у тебя наибольший интерес?',
              'Что из предложенных вариантов ты бы предпочел надеть?',
              'Какое место из представленных фотографий ты бы предпочел посетить?']]

answers = [[['золотой', 'бордовый', 'белый', 'розовый', 'черный', 'зеленый',
             'сиреневый', 'желтый'], ['Встречусь посплетничать с "подругами"',
                                      'Посмотрю фильм "Завтрак у Тиффани"',
                                      'Пойду кормить уточек',
                                      'Пострадаю от неразделенной "любви"',
                                      'Уеду из города, чтобы сменить обстановку ',
                                      'Сяду писать стихотворения',
                                      'Посмотрю фильм с друзьями и поем пиццу',
                                      'Почитаю глянцевые журналы',
                                      'Пойду на показ высокой моды'],
            ['история', 'рисование', 'химия', 'география', 'английский',
             'музыка', 'обществознание', 'литература'],
            ['платье с вырезом и высокий каблук', 'футболка и джинсы',
             'блузка, юбка, пиджак, заколка', 'рубашка и джинсы',
             'твидовый сарафан и блузка',
             'классическое сдержанное платье и ободок', 'рубашка и брюки',
             'легкий сарафан'], [
                'https://github.com/AndrushaUt/GossipSurvey/blob/main/photos/girl6.jpg?raw=true',
                'https://github.com/AndrushaUt/GossipSurvey/blob/main/photos/girl2.jpg?raw=true',
                'https://github.com/AndrushaUt/GossipSurvey/blob/main/photos/girl4.jpg?raw=true',
                'https://github.com/AndrushaUt/GossipSurvey/blob/main/photos/girl%208.jpg?raw=true']],
           [
               ['черный', 'белый', 'синий', 'сиреневый', 'голубой',
                'оранжевый', 'серый', 'коричневый'],
               ['Займусь спортом', 'Буду грустить в одиночестве',
                'Пересмотрю старые фильмы', 'Схожу в бар',
                'Пойду прогуляюсь с другом', 'Сяду почитать',
                'Поиздеваюсь над своим окружением', 'Схожу на свидание'],
               ['математика', 'физкультура', 'химия', 'история', 'география',
                'биология', 'обществознание', 'литература'],
               ['классический костюм', 'футболка, пиджак, джинсы',
                'рубашка и джинсы', 'рубашка, жилетка, брюки',
                'спортивный костюм', 'рубашка, брюки, подтяжки',
                'свитер и джинсы', 'рубашка, кардиган, джинсы'],
               [
                   'https://github.com/AndrushaUt/GossipSurvey/blob/main/photos/boy4.jpg?raw=true',
                   'https://github.com/AndrushaUt/GossipSurvey/blob/main/photos/boy6.jpg?raw=true',
                   'https://github.com/AndrushaUt/GossipSurvey/blob/main/photos/boy8.jpg?raw=true',
                   'https://github.com/AndrushaUt/GossipSurvey/blob/main/photos/boy2.jpg?raw=true']]]

points_of_answers = {'золотой': 2, 'бордовый': 2, 'белый': 8, 'розовый': 4,
                     'черный': 2, 'зеленый': 6, 'сиреневый': 2, 'желтый': 8,
                     'Встречусь посплетничать с "подругами"': 2,
                     'Посмотрю фильм "Завтрак у Тиффани"': 2,
                     'Пойду кормить уточек': 2,
                     'Пострадаю от неразделенной "любви"': 4,
                     'Уеду из города, чтобы сменить обстановку': 4,
                     'Сяду писать стихотворения': 8,
                     'Посмотрю фильм с друзьями и поем пиццу': 8,
                     'Почитаю глянцевые журналы': 6,
                     'Пойду на показ высокой моды': 6, 'история': 6,
                     'рисование': 6, 'химия': 8, 'география': 4,
                     'английский': 2, 'музыка': 8, 'обществознание': 8,
                     'литература': 6, 'платье с вырезом и высокий каблук': 4,
                     'футболка и джинсы': 6,
                     'блузка, юбка, пиджак, заколка': 2, 'рубашка и джинсы': 4,
                     'твидовый сарафан и блузка': 6,
                     'классическое сдержанное платье и ободок': 2,
                     'рубашка и брюки': 4, 'легкий сарафан': 8,
                     'https://github.com/AndrushaUt/GossipSurvey/blob/main/photos/girl6.jpg?raw=true': 6,
                     'https://github.com/AndrushaUt/GossipSurvey/blob/main/photos/girl2.jpg?raw=true': 2,
                     'https://github.com/AndrushaUt/GossipSurvey/blob/main/photos/girl4.jpg?raw=true': 4,
                     'https://github.com/AndrushaUt/GossipSurvey/blob/main/photos/girl%208.jpg?raw=true': 8,
                     'синий': 6, 'голубой': 4, 'оранжевый': 8, 'серый': 4,
                     'коричневый': 6, 'Займусь спортом': 4,
                     'Буду грустить в одиночестве': 8,
                     'Пересмотрю старые фильмы': 6, 'Схожу в бар': 2,
                     'Пойду прогуляюсь с другом': 8, 'Сяду почитать': 4,
                     'Поиздеваюсь над своим окружением': 2,
                     'Схожу на свидание': 4, 'математика': 2, 'физкультура': 4,
                     'биология': 2, 'классический костюм': 2,
                     'футболка, пиджак, джинсы': 6,
                     'рубашка, жилетка, брюки': 8, 'спортивный костюм': 4,
                     'рубашка, брюки, подтяжки': 2, 'свитер и джинсы': 8,
                     'рубашка, кардиган, джинсы': 6,
                     'https://github.com/AndrushaUt/GossipSurvey/blob/main/photos/boy4.jpg?raw=true': 4,
                     'https://github.com/AndrushaUt/GossipSurvey/blob/main/photos/boy6.jpg?raw=true': 6,
                     'https://github.com/AndrushaUt/GossipSurvey/blob/main/photos/boy8.jpg?raw=true': 8,
                     'https://github.com/AndrushaUt/GossipSurvey/blob/main/photos/boy2.jpg?raw=true': 2}


def check_validation_of_user_input(user_input, amount_of_answers):
    try:
        temp = int(user_input)
    except ValueError:
        return False
    if 1 <= int(user_input) <= amount_of_answers:
        return True
    return False


while True:
    points_of_survey = 0
    print(
        'Добро Пожаловать в Тест "Кто ты из сериала Сплетница". Давайте начнем')
    print("1. Укажите Ваш пол.")
    print(f"    1) женский")
    print(f"    2) мужской")
    sex = input("Ваш ответ: ")
    if sex != '1' and sex != '2':
        print(
            "Вы ввели некорректный номер ответа, поэтому тест начнется заново")
        print()
        continue
    sex = int(sex) - 1
    print()
    correction_input_status = True
    for i in range(5):
        print(f"{i + 2}. {questions[sex][i]}")
        print("Выбери из списка вариант наиболее хорошо подходящий тебе")
        if i != 4:
            for j in range(len(answers[sex][i])):
                print(f"    ({j + 1}) {answers[sex][i][j]}")
        else:
            plt.plot([1, 2, 3])
            plt.close()
            fig = plt.figure(figsize=(8, 8))
            for j in range(len(answers[sex][i])):
                response = requests.get(answers[sex][i][j])
                img = Image.open(BytesIO(response.content))
                fig.add_subplot(2, 2, j + 1)
                plt.axis("off")
                plt.imshow(img)
            plt.pause(0.1)
        answer = input("Ваш ответ: ")
        if not check_validation_of_user_input(answer,len(answers[sex][i])):
            print(
                "Вы ввели некорректный номер ответа, поэтому тест начнется заново")
            print()
            correction_input_status = False
            break
        answer = int(answer)
        points_of_survey += points_of_answers[answers[sex][i][answer - 1]]
    if not correction_input_status:
        continue
    points_of_survey *= (-1) ** sex
    if -40 <= points_of_survey <= -31:
        print("Поздравляю! Ты Эрик ван дер Вудсен")
    elif -30 <= points_of_survey <= -21:
        print("Поздравляю! Ты Дэн Хамфри")
    elif -20 <= points_of_survey <= -11:
        print("Поздравляю! Ты Нейт Арчибальд")
    elif points_of_survey == -10:
        print("Поздравляю! Ты Чак Басс")
    elif points_of_survey == 10:
        print("Поздравляю! ТыБлэр Вальдорф")
    elif 11 <= points_of_survey <= 20:
        print("Поздравляю! Ты Серена ван дер Вудсен")
    elif 21 <= points_of_survey <= 30:
        print("Поздравляю! Ты Дженни Хамфри")
    else:
        print("Поздравляю! Ты Ванесса Абрамс")
    break
# Out:
# Добро Пожаловать в Тест "Кто ты из сериала Сплетница". Давайте начнем
# 1. Укажите Ваш пол.
#     1) женский
#     2) мужской
# Ваш ответ: 3
# Вы ввели некорректный номер ответа, поэтому тест начнется заново
#
# Добро Пожаловать в Тест "Кто ты из сериала Сплетница". Давайте начнем
# 1. Укажите Ваш пол.
#     1) женский
#     2) мужской
# Ваш ответ: 1
#
# 2. Какой твой любимый цвет?
# Выбери из списка вариант наиболее хорошо подходящий тебе
#     (1) золотой
#     (2) бордовый
#     (3) белый
#     (4) розовый
#     (5) черный
#     (6) зеленый
#     (7) сиреневый
#     (8) желтый
# Ваш ответ: 1
# 3. Чем бы ты предпочла заниматься в свободное время?
# Выбери из списка вариант наиболее хорошо подходящий тебе
#     (1) Встречусь посплетничать с "подругами"
#     (2) Посмотрю фильм "Завтрак у Тиффани"
#     (3) Пойду кормить уточек
#     (4) Пострадаю от неразделенной "любви"
#     (5) Уеду из города, чтобы сменить обстановку
#     (6) Сяду писать стихотворения
# ...
